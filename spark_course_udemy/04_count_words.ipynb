# %%
import re

def normalizeWords(text):
    return re.compile(r'\W+', re.UNICODE).split(text.lower())

input = sc.textFile("file:///SparkCourse/2015-10-01_06-00-53__book.txt")
words = input.flatMap(normalizeWords)
wordCounts = words.map(lambda x:(x,1)).reduceByKey(lambda x,y:x+y).map(lambda (x,y): (y,x)).sortByKey().collect()


for result in wordCounts:
    count = str(result[0])
    word = result[1].encode('ascii', 'ignore')
    if (word):
        print word + ":\t\t" + count
# Out:
# hats:		1
# desirable:		1
# four:		1
# relationships:		1
# extrapolate:		1
# adaptive:		1
# fondly:		1
# announced:		1
# force:		1
# consistent:		1
# electricians:		1
# asia:		1
# mailings:		1
# disposable:		1
# 104:		1
# obtained:		1
# forum:		1
# harass:		1
# calculations:		1
# astute:		1
# criticism:		1
# psychological:		1
# conflicts:		1
# achievable:		1
# counts:		1
# landscape:		1
# catchy:		1
# hospital:		1
# strike:		1
# separated:		1
# award:		1
# 93:		1
# outdated:		1
# divorced:		1
# pursue:		1
# roof:		1
# exceptions:		1
# addictive:		1
# household:		1
# appointment:		1
# machine:		1
# hot:		1
# fudge:		1
# mouths:		1
# curiosity:		1
# chump:		1
# types:		1
# attempt:		1
# attracts:		1
# teammates:		1
# goodbye:		1
# realizing:		1
# salon:		1
# rewarded:		1
# digest:		1
# edits:		1
# 401:		1
# weeks:		1
# versus:		1
# affected:		1
# prevented:		1
# unemployed:		1
# reaches:		1
# niches:		1
# reasonably:		1
# laying:		1
# legwork:		1
# substantially:		1
# reminding:		1
# ...
